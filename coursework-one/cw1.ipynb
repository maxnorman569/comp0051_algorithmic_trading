# %%
import numpy as np
import requests

import matplotlib.pyplot as plt
import seaborn as sns

import configparser

import alphavantagelink as av
from utils import get_api_key

# %%
API_KEY = get_api_key('ALPHA_VANTAGE_KEY')
ticks, open, high, low, close, volume = av.get_intra_day(API_KEY, 'VALE', '1min', 'false', 'full')

# %%
plt.plot(open)

# TODO: 
# - add title
# - fix y axis
# - fix x axis by making date time

# %%
ticks
# Out:
# ['2023-02-03 19:59:00',
#  '2023-02-03 18:34:00',
#  '2023-02-03 18:29:00',
#  '2023-02-03 17:20:00',
#  '2023-02-03 16:05:00',
#  '2023-02-03 16:01:00',
#  '2023-02-03 16:00:00',
#  '2023-02-03 15:59:00',
#  '2023-02-03 15:58:00',
#  '2023-02-03 15:57:00',
#  '2023-02-03 15:56:00',
#  '2023-02-03 15:55:00',
#  '2023-02-03 15:54:00',
#  '2023-02-03 15:53:00',
#  '2023-02-03 15:52:00',
#  '2023-02-03 15:51:00',
#  '2023-02-03 15:50:00',
#  '2023-02-03 15:49:00',
#  '2023-02-03 15:48:00',
#  '2023-02-03 15:47:00',
#  '2023-02-03 15:46:00',
#  '2023-02-03 15:45:00',
#  '2023-02-03 15:44:00',
#  '2023-02-03 15:43:00',
#  '2023-02-03 15:42:00',
#  '2023-02-03 15:41:00',
#  '2023-02-03 15:40:00',
#  '2023-02-03 15:39:00',
#  '2023-02-03 15:38:00',
#  '2023-02-03 15:37:00',
#  '2023-02-03 15:36:00',
#  '2023-02-03 15:35:00',
#  '2023-02-03 15:34:00',
#  '2023-02-03 15:33:00',
#  '2023-02-03 15:32:00',
#  '2023-02-03 15:31:00',
#  '2023-02-03 15:30:00',
#  '2023-02-03 15:29:00',
# ...

# %%
plt.plot(open[-300:])
