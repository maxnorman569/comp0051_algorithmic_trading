# %%
# https://data.nasdaq.com/tools/python

import nasdaqdatalink
import matplotlib.pyplot as plt

data = nasdaqdatalink.get('NSE/OIL')

data['Open'].plot()
plt.tight_layout()
plt.title('NSE/OIL')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LimitExceededError                        Traceback (most recent call last)
# Cell In[1], line 6
#       3 import nasdaqdatalink
#       4 import matplotlib.pyplot as plt
# ----> 6 data = nasdaqdatalink.get('NSE/OIL')
#       8 data['Open'].plot()
#       9 plt.tight_layout()
#
# File ~/UCL/term_2/algorithmic_trading/comp0051_env/lib/python3.10/site-packages/nasdaqdatalink/get.py:48, in get(dataset, **kwargs)
#      46     if dataset_args['column_index'] is not None:
#      47         kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48     data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49 # Array
#      50 elif isinstance(dataset, list):
#
# File ~/UCL/term_2/algorithmic_trading/comp0051_env/lib/python3.10/site-packages/nasdaqdatalink/model/dataset.py:47, in Dataset.data(self, **options)
#      45 updated_options = Util.merge_options('params', params, **options)
#      46 try:
# ---> 47     return Data.all(**updated_options)
#      48 except NotFoundError:
#      49     if handle_not_found_error:
#
# File ~/UCL/term_2/algorithmic_trading/comp0051_env/lib/python3.10/site-packages/nasdaqdatalink/operations/list.py:15, in ListOperation.all(cls, **options)
#      13     options['params'] = {}
#      14 path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15 r = Connection.request('get', path, **options)
#      16 response_data = r.json()
#      17 Util.convert_to_dates(response_data)
#
# File ~/UCL/term_2/algorithmic_trading/comp0051_env/lib/python3.10/site-packages/nasdaqdatalink/connection.py:40, in Connection.request(cls, http_verb, url, **options)
#      36 options['headers'] = headers
#      38 abs_url = '%s/%s' % (ApiConfig.api_base, url)
# ---> 40 return cls.execute_request(http_verb, abs_url, **options)
#
# File ~/UCL/term_2/algorithmic_trading/comp0051_env/lib/python3.10/site-packages/nasdaqdatalink/connection.py:52, in Connection.execute_request(cls, http_verb, url, **options)
#      47 response = session.request(method=http_verb,
#      48                            url=url,
#      49                            verify=ApiConfig.verify_ssl,
#      50                            **options)
#      51 if response.status_code < 200 or response.status_code >= 300:
# ---> 52     cls.handle_api_error(response)
#      53 else:
#      54     return response
#
# File ~/UCL/term_2/algorithmic_trading/comp0051_env/lib/python3.10/site-packages/nasdaqdatalink/connection.py:120, in Connection.handle_api_error(cls, resp)
#     109 d_klass = {
#     110     'L': LimitExceededError,
#     111     'M': InternalServerError,
#    (...)
#     116     'X': ServiceUnavailableError
#     117 }
#     118 klass = d_klass.get(code_letter, DataLinkError)
# --> 120 raise klass(message, resp.status_code, resp.text, resp.headers, code)
#
# LimitExceededError: (Status 429) (Nasdaq Data Link Error QELx01) You have exceeded the anonymous user limit of 50 calls per day. To make more calls today, please register for a free Nasdaq Data Link account and then include your API key with your requests.

# %%
ICPM = nasdaqdatalink.get('UCOM/ICPM_VNM', start_date='2001-12-31', end_date='2019-12-31')
ICPM.tail()
# Out:
#             Chlorine - Import - Trade (USD)  Chlorine - Import - Weight (Kg)  \
# Date
# 2013-12-31                         59577.00                          84996.0
# 2014-12-31                        121578.00                         176022.0
# 2015-12-31                        119385.00                              NaN
# 2016-12-31                        141851.58                              NaN
# 2017-12-31                         87115.00                              NaN
#
#             Iodine - Import - Trade (USD)  Iodine - Import - Weight (Kg)  \
# Date
# 2013-12-31                      540311.00                    8577.000000
# 2014-12-31                      431207.00                    7941.000000
# 2015-12-31                      333711.00                    8480.000000
# 2016-12-31                      689580.69                   29323.596810
# 2017-12-31                     1168001.70                   56098.126871
#
#             Fluorine; bromine - Import - Trade (USD)  \
# Date
# 2013-12-31                                   8186.00
# 2014-12-31                                  17059.00
# 2015-12-31                                   9505.00
# 2016-12-31                                  10151.07
# 2017-12-31                                  10762.80
#
#             Fluorine; bromine - Import - Weight (Kg)  \
# Date
# 2013-12-31                               2263.000000
# 2014-12-31                               5705.000000
# 2015-12-31                               2987.000000
# 2016-12-31                               3464.642818
# 2017-12-31                               3028.151290
#
#             Sulphur; sublimed or precipitated; colloidal sulphur - Import - Trade (USD)  \
# Date
# 2013-12-31                                         1349862.00
# 2014-12-31                                          976522.00
# 2015-12-31                                         1037339.00
# 2016-12-31                                          860106.51
# 2017-12-31                                          947957.90
#
#             Sulphur; sublimed or precipitated; colloidal sulphur - Import - Weight (Kg)  \
# Date
# 2013-12-31                                      704670.000000
# 2014-12-31                                      544016.000000
# 2015-12-31                                      873182.000000
# 2016-12-31                                                NaN
# 2017-12-31                                      905250.061739
#
#             Carbon (carbon blacks and other forms of carbon; nes) - Import - Trade (USD)  \
# Date
# 2013-12-31                                       8.731970e+07
# 2014-12-31                                       1.042129e+08
# 2015-12-31                                       8.764128e+07
# 2016-12-31                                       8.882767e+07
# 2017-12-31                                       1.380553e+08
#
#             Carbon (carbon blacks and other forms of carbon; nes) - Import - Weight (Kg)  \
# Date
# 2013-12-31                                       5.102002e+07
# 2014-12-31                                       6.376879e+07
# 2015-12-31                                       5.510022e+07
# 2016-12-31                                       9.208676e+07
# 2017-12-31                                       1.295705e+08
#
#             ...  Strontium and barium - Import - Trade (USD)  \
# Date        ...
# 2013-12-31  ...                                          NaN
# 2014-12-31  ...                                          NaN
# 2015-12-31  ...                                          NaN
# 2016-12-31  ...                                          NaN
# 2017-12-31  ...                                          NaN
#
#             Strontium and barium - Import - Weight (Kg)  \
# Date
# 2013-12-31                                         None
# 2014-12-31                                         None
# 2015-12-31                                         None
# 2016-12-31                                         None
# 2017-12-31                                         None
#
#             Barium chloride - Import - Trade (USD)  \
# Date
# 2013-12-31                                     NaN
# 2014-12-31                                     NaN
# 2015-12-31                                     NaN
# 2016-12-31                                     NaN
# 2017-12-31                                     NaN
#
#             Barium chloride - Import - Weight (Kg)  \
# Date
# 2013-12-31                                     NaN
# 2014-12-31                                     NaN
# 2015-12-31                                     NaN
# 2016-12-31                                     NaN
# 2017-12-31                                     NaN
#
#             Bismuth nitrates - Import - Trade (USD)  \
# Date
# 2013-12-31                                      NaN
# 2014-12-31                                      NaN
# 2015-12-31                                      NaN
# 2016-12-31                                      NaN
# 2017-12-31                                      NaN
#
#             Bismuth nitrates - Import - Weight (Kg)  \
# Date
# 2013-12-31                                     None
# 2014-12-31                                     None
# 2015-12-31                                     None
# 2016-12-31                                     None
# 2017-12-31                                     None
#
#             Potassium dichromate - Import - Trade (USD)  \
# Date
# 2013-12-31                                          NaN
# 2014-12-31                                          NaN
# 2015-12-31                                          NaN
# 2016-12-31                                          NaN
# 2017-12-31                                          NaN
#
#             Potassium dichromate - Import - Weight (Kg)  \
# Date
# 2013-12-31                                          NaN
# 2014-12-31                                          NaN
# 2015-12-31                                          NaN
# 2016-12-31                                          NaN
# 2017-12-31                                          NaN
#
#             Isotopes nes; compounds - Export - Trade (USD)  \
# Date
# 2013-12-31                                             NaN
# 2014-12-31                                             NaN
# 2015-12-31                                             NaN
# 2016-12-31                                             NaN
# 2017-12-31                                             NaN
#
#             Isotopes nes; compounds - Export - Weight (Kg)
# Date
# 2013-12-31                                            None
# 2014-12-31                                            None
# 2015-12-31                                            None
# 2016-12-31                                            None
# 2017-12-31                                            None
#
# [5 rows x 691 columns]

# %%
ICPM['Carbon (carbon blacks and other forms of carbon; nes) - Import - Trade (USD)'].plot()
plt.tight_layout()
plt.title('Import')
plt.grid()
plt.show()
